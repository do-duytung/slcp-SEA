# %%
import pytz
import datetime
import os
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup as soup
import urllib.request as ul
from csv import writer

token = 'b1cede462ae6739ef0536814b6440f0e1ae05b73'
link = 'https://api.waqi.info/feed/'
# station = 'A231934'
#PATH = '/home/ec2-user/'
# Load station id from csv
stations = pd.read_csv('stations_list.csv')
output = 'aqicn_SEA_data.csv'

# Request data for all OK stations in the list
for i in range(len(stations)):
    lat = stations.iloc[i,0]
    lon = stations.iloc[i,1]
    id = stations.iloc[i,2]
    print(id)
    url = link + id +'/?token=' + token
    response = requests.get(url)
    data = json.loads(response.text)
    # Load data from json file
    tstamp = data['data']['time']['s']
    List = [tstamp,lat,lon,id]
    iaqi = ['pm25', 'o3', 'no2', 'so2', 'co', 't', 'p', 'h', 'w']
    for item in iaqi:
        if item in data['data']['iaqi']:
            item = data['data']['iaqi'][item]['v']
        else:
            item = 'NA'
        List.append(item)
    print(List)
    with open(output, 'a') as f:
        filewriter = writer(f)
        filewriter.writerow(List)
    f.close()

# # Scrape data of the last 4 stations
# def scraping():
#     pagesoup = soup(htmldata, "html.parser")
#     HAN = pytz.timezone('Asia/Saigon')
#     tstamp = datetime.datetime.now(HAN)
#     #itemlocator = pagesoup.findAll('div uk-grid', {"class":"uk-grid"})
#     pm25 = getattr(pagesoup.find('td', {"id":"cur_pm25"}), 'text', 'NA')
#     o3 = getattr(pagesoup.find('td', {"id":"cur_o3"}), 'text', 'NA')
#     no2 = getattr(pagesoup.find('td', {"id":"cur_no2"}), 'text', 'NA')
#     so2 = getattr(pagesoup.find('td', {"id":"cur_so2"}), 'text', 'NA')
#     co = getattr(pagesoup.find('td', {"id":"cur_co"}), 'text', 'NA')
#     t = getattr(pagesoup.find('td', {"id":"cur_t"}), 'text', 'NA')
#     p = getattr(pagesoup.find('td', {"id":"cur_p"}), 'text', 'NA')
#     h = getattr(pagesoup.find('td', {"id":"cur_h"}), 'text', 'NA')
#     w = getattr(pagesoup.find('td', {"id":"cur_w"}), 'text', 'NA')
    
#     List = [tstamp,station,id,pm25,o3,no2,so2,co,t,p,h,w]
       
#     headers = "Tstamp, Station, PM25, Ozone, NO2, SO2, CO, Temp, Pressure, Humidity, Windspeed\n"
#     if not os.path.isfile(output):
#         with open(output, "w", encoding="utf-8") as f:
#             f.write(headers)
    
#     with open(output, "a", newline='', encoding="utf-8") as f:    
#         writer_obj = writer(f)
#         writer_obj.writerow(List)   
#     return List

# for i in range(len(stations)-4,len(stations)):
#     lat = stations.iloc[i,0]
#     lon = stations.iloc[i,1]
#     link = stations.iloc[i,3]
#     id = stations.iloc[i,2]
#     req = ul.Request(link, headers={'User-Agent':'Mozilla/5.0'})
#     client = ul.urlopen(req)
#     htmldata = client.read()
#     client.close()
#     scraping()
# Out:
# beijing
# ['2024-07-16 18:00:00', 39.9, 116.06, 'beijing', 55, 54.5, 3.7, 2.1, 4.6, 29, 1002, 74, 0.5]
# tangshan
# ['2024-07-16 18:00:00', 39.62, 118.01, 'tangshan', 78, 61.7, 5.1, 0.6, 4.6, 28, 1001, 78, 1.5]
# datong
# ['2024-07-16 18:00:00', 40.09, 113.13, 'datong', 55, 36, 6, 4.6, 2.8, 25, 890.1, 42, 8]
# tianjin
# ['2024-07-16 18:00:00', 39.12, 116.63, 'tianjin', 114, 27, 6.9, 3.1, 10, 28, 1001, 78, 1.5]
# cangzhou
# ['2024-07-16 18:00:00', 38.31, 116.7, 'cangzhou', 109, 57.1, 4.2, 2.1, 2.8, 28, 1001, 78, 1.5]
# taiyuan
# ['2024-07-16 18:00:00', 37.86, 112.37, 'taiyuan', 50, 'NA', 6.4, 2.6, 6.4, 31, 1005, 45, 1.5]
# luliang
# ['2024-07-16 18:00:00', 37.51, 111.04, 'luliang', 13, 31.7, 3.2, 1.1, 3.7, 31.1, 897.9, 47.1, 2]
# xingtai
# ['2024-07-16 18:00:00', 37.07, 114.32, 'xingtai', 82, 57.1, 1, 1.6, 6.4, 28.8, 980.9, 74, 1]
# hengshui
# ['2024-07-16 18:00:00', 37.74, 115.5, 'hengshui', 91, 51.9, 1.9, 1.1, 3.7, 29.2, 1000.4, 74.1, 2]
# dezhou
# ['2024-07-16 18:00:00', 37.44, 116.15, 'dezhou', 61, 41.5, 3.2, 3.6, 0.1, 28.9, 999.7, 77.2, 2]
# binzhou
# ['2024-07-16 18:00:00', 37.4, 117.64, 'binzhou', 65, 43.1, 7.8, 1.6, 0.1, 27.3, 1000.3, 98.8, 1]
# dongying
# ['2024-07-16 18:00:00', 37.43, 118.29, 'dongying', 38, 22.8, 5.1, 5.1, 0.1, 28.4, 999.9, 83.8, 2]
# weifang
# ['2024-07-16 17:00:00', 36.72, 118.96, 'weifang', 57, 27.3, 3.2, 3.6, 0.1, 28.4, 999.9, 83.8, 2]
# yantai
# ['2024-07-16 18:00:00', 37.54, 121.21, 'yantai', 13, 28.9, 1.4, 3.1, 0.1, 12.8, 1013.5, 85, 3.4]
# weihai
# ['2024-07-16 18:00:00', 37.48, 121.91, 'weihai', 9, 25.2, 6, 3.6, 0.1, 12.9, 1013.5, 85, 4.6]
# qingdao
# ['2024-07-16 18:00:00', 36.136, 120.03, 'qingdao', 38, 37.8, 6.9, 3.6, 0.1, 26, 1004, 100, 6.6]
# zibo
# ['2024-07-16 18:00:00', 36.82, 117.88, 'zibo', 30, 24.4, 5.1, 3.6, 0.1, 27, 968.8, 82.2, 5]
# jinan
# ['2024-07-16 17:00:00', 36.64, 116.69, 'jinan', 21, 25.6, 5.1, 4.1, 0.1, 26.7, 982.8, 94.3, 2]
# taian
# ['2024-07-16 18:00:00', 36.15, 116.97, 'taian', 21, 22, 4.2, 4.6, 0.1, 19.8, 841.3, 100, 5]
# handan
# ['2024-07-16 18:00:00', 36.6, 114.31, 'handan', 65, 53.2, 1, 1.6, 3.7, 28.8, 980.9, 74, 1]
# liaocheng
# ['2024-07-16 18:00:00', 36.44, 115.82, 'liaocheng', 95, 38.6, 6.4, 4.1, 0.1, 29.7, 997.5, 76.8, 2]
# anyang
# ['2024-07-16 18:00:00', 36.1, 114.18, 'anyang', 76, 114.1, 1, 1.6, 5.5, 30.7, 979.2, 65.9, 2]
# changzhi
# ['2024-07-16 18:00:00', 36.18, 112.95, 'changzhi', 87, 'NA', 8.3, 2.6, 10.9, 30.1, 929.1, 74, 4]
# hebi
# ['2024-07-16 18:00:00', 35.75, 114.21, 'hebi', 129, 'NA', 5.5, 1.1, 6.4, 30.7, 979.2, 65.9, 2]
# puyang
# ['2024-07-16 18:00:00', 35.76, 114.85, 'puyang', 89, 'NA', 3.7, 2.1, 8.2, 30.7, 979.2, 65.9, 2]
# jining
# ['2024-07-16 18:00:00', 35.39, 116.43, 'jining', 21, 17.5, 1.9, 5.6, 0.1, 28.5, 996.6, 77.1, 5]
# linyi
# ['2024-07-16 18:00:00', 35.05, 118.0, 'linyi', 25, 24.8, 1.9, 4.1, 0.1, 27.6, 985.2, 87.8, 4]
# rizhao
# ['2024-07-16 18:00:00', 35.44, 119.16, 'rizhao', 95, 26.9, 6.4, 3.6, 0.1, 26.1, 997.5, 95.9, 2]
# lianyungang
# ['2024-07-16 18:00:00', 34.59, 118.87, 'lianyungang', 114, 'NA', 8.7, 2.6, 4.6, 28.3, 1004.1, 93.2, 1]
# zaozhuang
# ['2024-07-16 18:00:00', 34.81, 117.16, 'zaozhuang', 72, 33.8, 6.4, 1.1, 0.1, 27.6, 985.2, 87.8, 4]
# heze
# ['2024-07-16 18:00:00', 35.24, 115.13, 'heze', 34, 22, 1, 0.6, 0.1, 26.9, 996.5, 100, 4]
# xinxiang
# ['2024-07-16 18:00:00', 35.29, 113.72, 'xinxiang', 119, 'NA', 9.6, 2.6, 10.9, 28, 1002, 94, 1.5]
# zhengzhou
# ['2024-07-16 18:00:00', 34.74, 113.33, 'zhengzhou', 70, 'NA', 6.9, 0.6, 6.4, 28, 1002, 94, 1.5]
# xuzhou
# ['2024-07-16 18:00:00', 34.63, 116.87, 'xuzhou', 72, 'NA', 5.1, 3.6, 2.8, 29.6, 999, 84, 1]
# suqian
# ['2024-07-16 18:00:00', 33.94, 118.12, 'suqian', 59, 19.1, 6.4, 2.1, 5.5, 30.8, 1004, 83.1, 1]
# yancheng
# ['2024-07-16 18:00:00', 33.36, 119.99, 'yancheng', 82, 'NA', 4.6, 3.6, 7.3, 32.7, 1005, 75.1, 1]
# huaian
# ['2024-07-16 18:00:00', 33.6, 119.04, 'huaian', 70, 'NA', 7.4, 3.1, 3.7, 30.8, 1004, 83.1, 1]
# suzhou
# ['2024-07-16 18:00:00', 33.63, 116.82, 'suzhou', 55, 21.6, 3.7, 3.6, 6.4, 34, 1007, 59, 5.6]
# zhoukou
# ['2024-07-16 18:00:00', 33.61, 114.48, 'zhoukou', 87, 'NA', 5.5, 1.6, 6.4, 26.7, 996.6, 98.8, 1]
# pingdingshan
# ['2024-07-16 18:00:00', 33.73, 113.14, 'pingdingshan', 65, 'NA', 19.7, 0.6, 6.4, 28, 1002, 94, 1.5]
# xinyang
# ['2024-07-16 18:00:00', 32.11, 113.92, 'xinyang', 50, 'NA', 1.4, 3.1, 3.7, 30.2, 989.3, 78.8, 2]
# fuyang
# ['2022-10-02 20:00:00', 32.9, 115.67, 'fuyang', 109, 17.9, 16, 3.1, 6.4, 29, 1011, 74, 1.5]
# bengbu
# ['2024-07-16 18:00:00', 32.94, 117.19, 'bengbu', 63, 49.2, 3.2, 3.1, 5.5, 31.6, 1001.3, 81.8, 3]
# taizhou
# ['1970-01-01 00:00:00', 32.48, 119.75, 'taizhou', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# yangzhou
# ['2024-07-16 18:00:00', 32.41, 119.15, 'yangzhou', 55, 'NA', 7.4, 3.1, 5.5, 33, 1005, 66, 2.5]
# chuzhou
# ['2024-07-16 18:00:00', 32.3, 118.14, 'chuzhou', 82, 'NA', 2.8, 2.6, 5.5, 33, 1005, 66, 2.5]
# nanjing
# ['2024-07-16 18:00:00', 32.09, 118.4, 'nanjing', 72, 'NA', 7.4, 5.1, 8.2, 33, 1005, 66, 2.5]
# changzhou
# ['2024-07-16 18:00:00', 31.81, 119.61, 'changzhou', 72, 'NA', 4.6, 3.1, 3.7, 36.8, 1005.1, 51, 1]
# nantong
# ['2024-07-16 18:00:00', 32.01, 120.71, 'nantong', 70, 26.4, 16.5, 3.6, 4.6, 34, 1007, 59, 5.6]
# shanghai
# ['2024-07-16 18:00:00', 31.22, 120.81, 'shanghai', 61, 48.8, 8.3, 6.1, 4.6, 34, 1007, 59, 5.6]
# suzhou
# ['2024-07-16 18:00:00', 31.32, 119.12, 'suzhou', 55, 21.6, 3.7, 3.6, 6.4, 34, 1007, 59, 5.6]
# wuxi
# ['2024-07-16 18:00:00', 31.57, 120.14, 'wuxi', 65, 16, 6.9, 2.6, 22.6, 36.8, 1005.1, 51, 1]
# maanshan
# ['2024-07-16 18:00:00', 31.67, 118.34, 'maanshan', 63, 9.4, 4.2, 4.1, 5.5, 33, 1005, 66, 2.5]
# hefei
# ['2024-07-16 18:00:00', 31.85, 117.12, 'hefei', 102, 'NA', 9.2, 3.1, 6.4, 31, 1004, 84, 3.6]
# tongling
# ['2024-07-16 18:00:00', 31.89, 116.64, 'tongling', 95, 'NA', 4.2, 3.1, 4.6, 34.8, 1001.5, 61.8, 1]
# anqing
# ['2024-07-16 18:00:00', 30.53, 116.96, 'anqing', 74, 'NA', 11.9, 3.1, 6.4, 32.1, 998.7, 79.9, 1]
# xuancheng
# ['2024-07-16 18:00:00', 30.95, 118.75, 'xuancheng', 46, 'NA', 1.9, 3.1, 3.7, 34.8, 1001.5, 61.8, 1]
# chizhou
# ['2024-07-16 18:00:00', 29.72, 116.82, 'chizhou', 76, 24.8, 7.8, 3.1, 4.6, 32.1, 998.7, 79.9, 1]
# hangzhou
# ['2024-07-16 18:00:00', 30.26, 119.84, 'hangzhou', 55, 55.8, 9.6, 2.1, 6.4, 36, 1006, 47, 1.5]
# shaoxing
# ['2024-07-16 18:00:00', 29.62, 120.39, 'shaoxing', 46, 32.5, 8.7, 2.6, 4.6, 36, 1006, 47, 1.5]
# ningbo
# ['2024-07-16 18:00:00', 29.86, 121.24, 'ningbo', 70, 'NA', 2.3, 4.1, 5.5, 33, 1008, 66, 6.6]
# zhoushan
# ['1970-01-01 00:00:00', 29.81, 121.94, 'zhoushan', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# taizhou
# ['1970-01-01 00:00:00', 28.66, 121.08, 'taizhou', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# jinhua
# ['2024-07-16 18:00:00', 29.07, 119.48, 'jinhua', 34, 'NA', 3.2, 0.6, 2.8, 35.6, 990.4, 50.1, 4]
# quzhou
# ['2024-07-16 18:00:00', 28.95, 118.72, 'quzhou', 61, 'NA', 5.1, 2.1, 5.5, 36.7, 996.7, 48, 2]
# huangshan
# ['2024-07-16 18:00:00', 29.7, 118.15, 'huangshan', 55, 'NA', 2.3, 3.6, 3.7, 21.5, 818.3, 82, 1]
# jiujiang
# ['2024-07-16 18:00:00', 29.64, 115.77, 'jiujiang', 53, 50.6, 6.4, 4.1, 6.4, 25.8, 882.6, 78.1, 6]
# nanchang
# ['2024-07-16 18:00:00', 29.19, 115.28, 'nanchang', 38, 36.2, 2.8, 3.6, 2.8, 36.7, 999.7, 48, 3]
# fuzhoushi
# ['2024-07-16 18:00:00', 27.95, 116.2, 'fuzhoushi', 34, 28.5, 2.3, 0.6, 5.6, 36.7, 996.7, 44.9, 3]
# yingtan
# ['2024-07-16 18:00:00', 28.51, 115.79, 'yingtan', 70, 37.8, 0.5, 3.1, 1.9, 36.7, 996.7, 44.9, 3]
# shangrao
# ['2024-07-16 18:00:00', 27.55, 116.79, 'shangrao', 63, 43.1, 3.7, 2.6, 4.6, 36, 981, 46.9, 2]
# lishui
# ['2024-07-16 18:00:00', 28.32, 119.27, 'lishui', 70, 'NA', 2.8, 1.6, 4.6, 35.6, 990.4, 50.1, 4]
# wenzhou
# ['2024-07-16 18:00:00', 27.99, 120.51, 'wenzhou', 42, 9.8, 2.8, 2.6, 3.7, 30.9, 1005.3, 73.9, 4]
# ningde
# ['2024-07-16 18:00:00', 26.65, 119.45, 'ningde', 38, 'NA', 4.6, 3.1, 3.7, 32, 1009, 70, 2.5]
# nanping
# ['2024-07-16 18:00:00', 26.64, 118.08, 'nanping', 61, 'NA', 3.2, 2.1, 5.5, 34.5, 989.6, 53.9, 5]
# sanming
# ['2024-07-16 18:00:00', 26.25, 117.46, 'sanming', 57, 'NA', 6.4, 2.6, 4.6, 34.8, 977.8, 53, 3]
# longyan
# ['2024-07-16 18:00:00', 25.07, 116.86, 'longyan', 59, 'NA', 3.2, 1.1, 2.8, 33.6, 980.9, 51.1, 2]
# zhangzhou
# ['2023-08-03 19:00:00', 24.51, 117.51, 'zhangzhou', 68, 22, 0.5, 2.6, 2.5, 34, 998, 71, 4.6]
# xiamen
# ['2024-07-16 18:00:00', 24.47, 117.94, 'xiamen', 25, 'NA', 1, 1.1, 1, 33, 1009, 62, 4.6]
# quanzhou
# ['2024-07-16 18:00:00', 24.9, 118.41, 'quanzhou', 63, 'NA', 6.4, 2.1, 3.7, 33, 1009, 62, 4.6]
# putian
# ['2024-07-16 18:00:00', 25.41, 118.85, 'putian', 57, 'NA', 5.5, 3.1, 9.1, 32, 1009, 70, 2.5]
# fuzhou
# ['2024-07-16 18:00:00', 26.05, 119.15, 'fuzhou', 30, 'NA', 3.2, 2.6, 2.8, 32, 1009, 70, 2.5]
# chaozhou
# ['2024-07-16 18:00:00', 24.66, 114.97, 'chaozhou', 17, 14.3, 2.8, 1.6, 1.9, 29, 1009, 88, 1.5]
# meizhou
# ['2024-07-16 18:00:00', 25.47, 113.68, 'meizhou', 34, 19.1, 2.8, 2.1, 3.7, 29, 1009, 88, 1.5]
# heyuan
# ['2024-07-16 18:00:00', 23.72, 114.64, 'heyuan', 70, 21.6, 3.7, 2.1, 5.5, 31.2, 994.9, 72.6, 1]
# huizhou
# ['2024-07-16 18:00:00', 22.73, 114.06, 'huizhou', 30, 21.6, 0.5, 1.1, 4.6, 30, 1006.1, 80.6, 3]
# shanwei
# ['2024-07-16 18:00:00', 22.78, 115.27, 'shanwei', 13, 13.5, 3.7, 3.1, 4.6, 27.9, 1006.6, 86.8, 2]
# dongguan
# ['2024-07-16 18:00:00', 22.97, 113.46, 'dongguan', 46, 23.6, 5.5, 3.1, 6.4, 29, 1007, 79, 4.6]
# guangzhou
# ['2024-07-16 18:00:00', 23.12, 112.56, 'guangzhou', 61, 'NA', 'NA', 'NA', 'NA', 29, 1007, 83, 0.5]
# zhaoqing
# ['2024-07-16 18:00:00', 23.05, 112.31, 'zhaoqing', 38, 27.7, 6.4, 4.1, 4.6, 29, 1007.5, 83, 1]
# foshan
# ['2024-07-16 18:00:00', 23.0, 112.94, 'foshan', 42, 17.9, 6.9, 4.1, 5.5, 29, 1007, 83, 0.5]
# jiangmen
# ['2024-07-16 18:00:00', 22.56, 112.94, 'jiangmen', 53, 22.8, 4.2, 3.1, 2.8, 30, 1007, 89, 5.6]
# nanning
# ['2024-07-16 18:00:00', 22.8, 107.93, 'nanning', 46, 'NA', 4.6, 2.1, 3.7, 32, 1005, 62, 1.5]
# zhongshan
# ['2024-07-16 18:00:00', 22.51, 113.24, 'zhongshan', 46, 22, 6, 3.6, 5.5, 29, 1007, 79, 4.6]
# shenzhen
# ['2024-07-16 18:00:00', 22.55, 113.72, 'shenzhen', 42, 20.8, 16.5, 3.1, 4.6, 30, 1007, 89, 4.6]
# hongkong
# ['2024-07-16 18:00:00', 22.33, 114.12, 'hongkong', 35, 5.7, 23.4, 2.1, 4.7, 29.7, 1007.8, 89.3, 0.8]
# macau
# ['2024-07-16 18:00:00', 22.16, 113.52, 'macau', 46, 19.5, 8.7, 4.1, 4.6, 30, 1007, 89, 5.6]
# yangjiang
# ['2024-07-16 18:00:00', 21.78, 111.66, 'yangjiang', 13, 21.2, 2.3, 3.1, 3.7, 31.1, 995.3, 68.8, 6]
# maoming
# ['2024-07-16 18:00:00', 21.6, 110.82, 'maoming', 21, 19.9, 1.4, 4.1, 3.7, 30.3, 989.4, 76.9, 1]
# zhanjiang
# ['2024-07-16 18:00:00', 21.27, 110.2, 'zhanjiang', 42, 18.7, 2.3, 3.6, 5.5, 29.9, 999.4, 73.7, 5]
# baise
# ['2024-07-16 18:00:00', 23.1, 105.43, 'baise', 55, 'NA', 3.2, 3.6, 5.5, 34.4, 983.6, 57.8, 3]
# kunming
# ['2024-07-16 18:00:00', 24.93, 102.65, 'kunming', 25, 'NA', 2.8, 2.6, 3.7, 25, 1017, 53, 3.6]
# yangon
# ['2024-07-16 16:00:00', 16.83, 96.01, 'yangon', 17, 'NA', 'NA', 'NA', 'NA', 29, 1003, 83, 2]
# vientiane
# ['2024-07-16 17:00:00', 17.96, 102.52, 'vientiane', 25, 'NA', 'NA', 'NA', 'NA', 31.2, 981.1, 80.8, 1.5]
# chiangmai
# ['2024-07-16 17:00:00', 18.79, 98.87, 'chiangmai', 25, 14.6, 7.5, 0.6, 'NA', 33.5, 964.4, 7.7, 0.5]
# bangkok
# ['2024-07-16 17:00:00', 13.72, 100.3, 'bangkok', 54, 6.4, 1.2, 0.6, 0.1, 30.5, 1002.1, 93.1, 2]
# phnom-penh
# ['', 11.57, 104.72, 'phnom-penh', 'NA', 'NA', 'NA', 'NA', 'NA', 38, 1005, 35, 4.1]
# kuala-lumpur
# ['2024-07-16 17:00:00', 3.13, 101.6, 'kuala-lumpur', 'NA', 'NA', 'NA', 'NA', 'NA', 32, 1006, 59, 4.1]
# singapore
# ['2024-07-16 18:00:00', 1.34, 103.71, 'singapore', 72, 10, 'NA', 1, 3, 30, 1007, 66, 4.6]
# jakarta
# ['2024-07-16 16:00:00', 6.18, 106.83, 'jakarta', 80, 'NA', 'NA', 'NA', 'NA', 32.5, 1007, 47.5, 6.6]

# %%
import json
import requests
import pandas as pd

token = 'b1cede462ae6739ef0536814b6440f0e1ae05b73'
link = 'https://api.waqi.info/feed/'
#station = 'A233461'

stations = pd.read_csv('stations_list.csv')
for i in range(len(stations)):
    #print(stations['Link'][i])
    station = stations['id'][i]
    url = link + station +'/?token=' + token
    response = requests.get(url)
    data = json.loads(response.text)

    # Load data from json file
    List = [value['v'] for key, value in data['data']['iaqi'].items()]
    List.append(data['data']['time']['s'])
    tstamp = data['data']['time']['s']
    pm25 = data['data']['iaqi']['pm25']['v']
    print(tstamp,pm25)
# Out:
# 2024-07-16 18:00:00 55
# 2024-07-16 18:00:00 78
# 2024-07-16 18:00:00 55
# 2024-07-16 18:00:00 114
# 2024-07-16 18:00:00 109
# 2024-07-16 18:00:00 50
# 2024-07-16 18:00:00 13
# 2024-07-16 18:00:00 82
# 2024-07-16 18:00:00 91
# 2024-07-16 18:00:00 61
# 2024-07-16 18:00:00 65
# 2024-07-16 18:00:00 38
# 2024-07-16 18:00:00 42
# 2024-07-16 18:00:00 13
# 2024-07-16 18:00:00 9
# 2024-07-16 18:00:00 38
# 2024-07-16 18:00:00 30
# 2024-07-16 17:00:00 21
# 2024-07-16 18:00:00 21
# 2024-07-16 18:00:00 65
# 2024-07-16 18:00:00 95
# 2024-07-16 18:00:00 76
# 2024-07-16 18:00:00 87
# 2024-07-16 18:00:00 129
# 2024-07-16 18:00:00 89
# 2024-07-16 18:00:00 21
# 2024-07-16 18:00:00 25
# 2024-07-16 18:00:00 95
# 2024-07-16 18:00:00 114
# 2024-07-16 18:00:00 72
# 2024-07-16 18:00:00 34
# 2024-07-16 18:00:00 119
# 2024-07-16 18:00:00 70
# 2024-07-16 18:00:00 72
# 2024-07-16 18:00:00 59
# 2024-07-16 18:00:00 82
# 2024-07-16 18:00:00 70
# 2024-07-16 18:00:00 55
# 2024-07-16 18:00:00 87
# 2024-07-16 18:00:00 65
# 2024-07-16 18:00:00 50
# 2022-10-02 20:00:00 109
# 2024-07-16 18:00:00 63
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 18
#      15 data = json.loads(response.text)
#      17 # Load data from json file
# ---> 18 List = [value['v'] for key, value in data['data']['iaqi'].items()]
#      19 List.append(data['data']['time']['s'])
#      20 tstamp = data['data']['time']['s']
#
# AttributeError: 'list' object has no attribute 'items'
